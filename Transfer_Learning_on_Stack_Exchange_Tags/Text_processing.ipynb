# %%
import csv
import pandas as pd
import numpy as np
from IPython.display import display
from StopWords import stop_words
from bs4 import BeautifulSoup

biology_pd = pd.read_csv('./src/biology.csv')
cooking_pd = pd.read_csv('./src/cooking.csv')
crypto_pd = pd.read_csv('./src/crypto.csv')
diy_pd = pd.read_csv('./src/diy.csv')
robotics_pd = pd.read_csv('./src/robotics.csv')
travel_pd = pd.read_csv('./src/travel.csv')
test_pd = pd.read_csv('./src/test.csv')

print('total counts : ',biology_pd.shape[0])
display(biology_pd.head())
print('total counts : ',cooking_pd.shape[0])
display(cooking_pd.head())
print('total counts : ',crypto_pd.shape[0])
display(crypto_pd.head())
print('total counts : ',diy_pd.shape[0])
display(diy_pd.head())
print('total counts : ',robotics_pd.shape[0])
display(robotics_pd.head())
print('total counts : ',travel_pd.shape[0])
display(travel_pd.head())
print('total counts : ',test_pd.shape[0])
display(test_pd.head())
# Out:
# total counts :  13196
#    id                                              title  \
# 0   1  What is the criticality of the ribosome bindin...
# 1   2  How is RNAse contamination in RNA based experi...
# 2   3      Are lymphocyte sizes clustered in two groups?
# 3   4  How long does antibiotic-dosed LB maintain goo...
# 4   5        Is exon order always preserved in splicing?
#
#                                              content  \
# 0  <p>In prokaryotic translation, how critical fo...
# 1  <p>Does anyone have any suggestions to prevent...
# 2  <p>Tortora writes in <em>Principles of Anatomy...
# 3  <p>Various people in our lab will prepare a li...
# 4  <p>Are there any cases in which the splicing m...
#
#                                                 tags
# 0  ribosome binding-sites translation synthetic-b...
# 1                                   rna biochemistry
# 2                 immunology cell-biology hematology
# 3                                       cell-culture
# ...

# %%
biology_np = biology_pd[['title', 'content', 'tags']].as_matrix()
cooking_np = cooking_pd[['title', 'content', 'tags']].as_matrix()
crypto_np = crypto_pd[['title', 'content', 'tags']].as_matrix()
diy_np = diy_pd[['title', 'content', 'tags']].as_matrix()
robotics_np = robotics_pd[['title', 'content', 'tags']].as_matrix()
travel_np = travel_pd[['title', 'content', 'tags']].as_matrix()

def parse_html(data_np):
    for i in range(data_np.shape[0]):
        data_np[i,1] = BeautifulSoup(data_np[i,1],'html.parser')\
                        .get_text()\
                        .replace('\n', ' ')\
                
def to_list(data):
    for i in range(len(data)):
        data[i] = [''.join([ch for ch in word if word.isalnum()])for word in data[i].lower().split(' ')]
        
    return [word for chunck in data for word in chunck if word not in stop_words]

def save_csv(file_name, data, path=None):
    with open(path + file_name + '.csv', 'w') as csvfile:
        csv_writer = csv.writer(csvfile, delimiter=' ')
        csv_writer.writerow(data)

biology_x = to_list(biology_np[:,0] + ' ' + biology_np[:,1])
biology_y = to_list(biology_np[:,2])
cooking_x = to_list(cooking_np[:,0] + ' ' + cooking_np[:,1])
cooking_y = to_list(cooking_np[:,2])
crypto_x = to_list(crypto_np[:,0] + ' ' + crypto_np[:,1])
crypto_y = to_list(crypto_np[:,2])
diy_x = to_list(diy_np[:,0] + ' ' + diy_np[:,1])
diy_y = to_list(diy_np[:,2])
robotics_x = to_list(robotics_np[:,0] + ' ' + robotics_np[:,1])
robotics_y = to_list(robotics_np[:,2])
travel_x = to_list(travel_np[:,0] + ' ' + travel_np[:,1])
travel_y = to_list(travel_np[:,2])

#save_csv('biology_x', biology_x, './src/words/')
#save_csv('cooking_x', cooking_x, './src/words/')
#save_csv('crypto_x', crypto_x, './src/words/')
#save_csv('diy_x', diy_x, './src/words/')
#save_csv('robotics_x', robotics_x, './src/words/')
#save_csv('travel_x', travel_x, './src/words/')
#save_csv('biology_y', biology_y, './src/words/')
#save_csv('cooking_y', cooking_y, './src/words/')
#save_csv('crypto_y', crypto_y, './src/words/')
#save_csv('diy_y', diy_y, './src/words/')
#save_csv('robotics_y', robotics_y, './src/words/')
#save_csv('travel_y', travel_y, './src/words/')
