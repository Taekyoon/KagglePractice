# %%
import pandas as pd
from bs4 import BeautifulSoup
from StopWords import stop_words
from collections import defaultdict
import math

from IPython.display import display

test_data = pd.read_csv('./src/test.csv')
test_data_content_np = test_data['content'].as_matrix()

def clean_html(data):
    print('> cleaning html tags....')
    for i in range(len(data)):
        data[i] = BeautifulSoup(data[i],'html.parser').get_text().replace('\n',' ')
        if not i % 100:
            print('> clean_html proceeding: ' + str(i) + '/' + str(len(data)))

    return data

def delete_stopwords(data):
    return [word for word in data if word not in stop_words]

def setup_text(data):
    print('> setting up text....')
    data_list = list()
    for i, row in enumerate(data):
        data_list.append(delete_stopwords([word for word in row.lower().split(' ') if word.isalpha()]))
        if not i % 100:
            print('> setup_text proceeding: ' + str(i) + '/' + str(len(data)))

    return data_list

def build_tf_table(data):
    print('> building tf_table....')
    tf_table = list()
    for i, row in enumerate(data):
        word_count = 0
        tfFreqDict = defaultdict(int)
        for word in row:
            tfFreqDict[word] += 1
            word_count += 1
        display(tfFreqDict)
        for word in tfFreqDict:
            tfFreqDict[word] = tfFreqDict[word] / word_count

        tf_table.append(tfFreqDict)
        if not i % 100:
            print('> tf_table proceeding: ' + str(i) + '/' + str(len(data)))

    return tf_table

def build_idf_table(word_list, data):
    print('> building idf_table....')
    idf_table = defaultdict(int)
    for word in word_list:
        idf_table[word] = 0

    for i, row in enumerate(data):
        for word in set(row):
            idf_table[word] += 1
        if not i % 100:
            print('> idf_table proceeding: ' + str(i) + '/' + str(len(data)))

    for word in idf_table:
        idf_table[word] = math.log((len(data)+1)/(idf_table[word]))

    return idf_table

def create_word_list(data):
    print('> creating word list....')
    word_list = list()
    for i, row in enumerate(data):
        word_list = word_list + row
        print('> creating word_list: ' + str(i) + '/' + str(len(data)))

    return set(word_list)

def build_tfidf_table(data):
    print('> starting tfidf_table....')
    tf_table = build_tf_table(data)
    display(tf_table)
    idf_table = build_idf_table(create_word_list(data), data)
    display(idf_table)

    print('> building tfidf_table....')
    tfidf_table = list()
    for i, row in enumerate(tf_table):
        tfidfDict = defaultdict(int)
        for word in row:
            tfidfDict[word] = row[word]*idf_table[word]

        tfidf_table.append(tfidfDict)
        if not i % 100:
            print('> tfidf_table proceeding: ' + str(i) + '/' + str(len(tf_table)))

    return tfidf_table



content_data = setup_text(clean_html(test_data_content_np))
display(build_tfidf_table(content_data))
# Out:
# > cleaning html tags....
# > clean_html proceeding: 0/81926
# > clean_html proceeding: 100/81926
# > clean_html proceeding: 200/81926
# > clean_html proceeding: 300/81926
# > clean_html proceeding: 400/81926
# > clean_html proceeding: 500/81926
# > clean_html proceeding: 600/81926
# > clean_html proceeding: 700/81926
# > clean_html proceeding: 800/81926
# > clean_html proceeding: 900/81926
# > clean_html proceeding: 1000/81926
# > clean_html proceeding: 1100/81926
# > clean_html proceeding: 1200/81926
# > clean_html proceeding: 1300/81926
# > clean_html proceeding: 1400/81926
# > clean_html proceeding: 1500/81926
# > clean_html proceeding: 1600/81926
# > clean_html proceeding: 1700/81926
# > clean_html proceeding: 1800/81926
# > clean_html proceeding: 1900/81926
# > clean_html proceeding: 2000/81926
# > clean_html proceeding: 2100/81926
# > clean_html proceeding: 2200/81926
# > clean_html proceeding: 2300/81926
# > clean_html proceeding: 2400/81926
# > clean_html proceeding: 2500/81926
# > clean_html proceeding: 2600/81926
# > clean_html proceeding: 2700/81926
# > clean_html proceeding: 2800/81926
# > clean_html proceeding: 2900/81926
# > clean_html proceeding: 3000/81926
# > clean_html proceeding: 3100/81926
# > clean_html proceeding: 3200/81926
# > clean_html proceeding: 13200/81926
# > clean_html proceeding: 13300/81926
# > clean_html proceeding: 13400/81926
# > clean_html proceeding: 13500/81926
# > clean_html proceeding: 13600/81926
# > clean_html proceeding: 13700/81926
# > clean_html proceeding: 13800/81926
# > clean_html proceeding: 13900/81926
# > clean_html proceeding: 14000/81926
# > clean_html proceeding: 14100/81926
# > clean_html proceeding: 14200/81926
# > clean_html proceeding: 14300/81926
# > clean_html proceeding: 14400/81926
# > clean_html proceeding: 14500/81926
# > clean_html proceeding: 14600/81926
# > clean_html proceeding: 14700/81926
# > clean_html proceeding: 14800/81926
# > clean_html proceeding: 14900/81926
# > clean_html proceeding: 15000/81926
# > clean_html proceeding: 15100/81926
# > clean_html proceeding: 15200/81926
# > clean_html proceeding: 15300/81926
# > clean_html proceeding: 15400/81926
# > clean_html proceeding: 15500/81926
# > clean_html proceeding: 15600/81926
# > clean_html proceeding: 15700/81926
# > clean_html proceeding: 15800/81926
# > clean_html proceeding: 15900/81926
# > clean_html proceeding: 16000/81926
# > clean_html proceeding: 16100/81926
# > clean_html proceeding: 16200/81926
# > clean_html proceeding: 16300/81926
# > clean_html proceeding: 16400/81926
# > clean_html proceeding: 16500/81926
# > clean_html proceeding: 16600/81926
# > clean_html proceeding: 16700/81926
# > clean_html proceeding: 16800/81926
# > clean_html proceeding: 16900/81926
# > clean_html proceeding: 17000/81926
# > clean_html proceeding: 17100/81926
# > clean_html proceeding: 17200/81926
# > clean_html proceeding: 17300/81926
# > clean_html proceeding: 17400/81926
# > clean_html proceeding: 17500/81926
# > clean_html proceeding: 17600/81926
# > clean_html proceeding: 17700/81926
# > clean_html proceeding: 17800/81926
# > clean_html proceeding: 17900/81926
# > clean_html proceeding: 18000/81926
# > clean_html proceeding: 18100/81926
# > clean_html proceeding: 18200/81926
# > clean_html proceeding: 18300/81926
# > clean_html proceeding: 18400/81926
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-33dce357c551> in <module>()
#      99
#     100
# --> 101 content_data = setup_text(clean_html(test_data_content_np))
#     102 display(build_tfidf_table(content_data))
#
# <ipython-input-1-33dce357c551> in clean_html(data)
#      13     print('> cleaning html tags....')
#      14     for i in range(len(data)):
# ---> 15         data[i] = BeautifulSoup(data[i],'html.parser').get_text().replace('\n',' ')
#      16         if not i % 100:
#      17             print('> clean_html proceeding: ' + str(i) + '/' + str(len(data)))
#
# /Users/Taekyoon/Envs/kaggle/lib/python3.5/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     226             self.reset()
#     227             try:
# --> 228                 self._feed()
#     229                 break
#     230             except ParserRejectedMarkup:
#
# /Users/Taekyoon/Envs/kaggle/lib/python3.5/site-packages/bs4/__init__.py in _feed(self)
#     287         self.builder.reset()
#     288
# --> 289         self.builder.feed(self.markup)
#     290         # Close out any unfinished strings and close all the open tags.
#     291         self.endData()
#
# /Users/Taekyoon/Envs/kaggle/lib/python3.5/site-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     165         parser.soup = self.soup
#     166         try:
# --> 167             parser.feed(markup)
#     168         except HTMLParseError as e:
#     169             warnings.warn(RuntimeWarning(
#
# /usr/local/Cellar/python3/3.5.2_1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# /usr/local/Cellar/python3/3.5.2_1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/html/parser.py in goahead(self, end)
#     171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
# --> 173                     k = self.parse_endtag(i)
#     174                 elif startswith("<!--", i):
#     175                     k = self.parse_comment(i)
#
# /usr/local/Cellar/python3/3.5.2_1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/html/parser.py in parse_endtag(self, i)
#     419                 return gtpos
#     420
# --> 421         self.handle_endtag(elem.lower())
#     422         self.clear_cdata_mode()
#     423         return gtpos
#
# /Users/Taekyoon/Envs/kaggle/lib/python3.5/site-packages/bs4/builder/_htmlparser.py in handle_endtag(self, name)
#      66
#      67     def handle_endtag(self, name):
# ---> 68         self.soup.handle_endtag(name)
#      69
#      70     def handle_data(self, data):
#
# /Users/Taekyoon/Envs/kaggle/lib/python3.5/site-packages/bs4/__init__.py in handle_endtag(self, name, nsprefix)
#     474     def handle_endtag(self, name, nsprefix=None):
#     475         #print "End tag: " + name
# --> 476         self.endData()
#     477         self._popToTag(name, nsprefix)
#     478
#
# KeyboardInterrupt:
